# %% [markdown]
# # Forge-LLM: load and generate
#
# Placeholder notebook. Real cells land in Phase H (release).
#
# Will demo:
# - `pip install forge-llm`
# - `from_pretrained` from HF Hub
# - streaming generation on free Colab
#
# See `docs/04_roadmap.md` and BUILD_PLAN.md §10.
